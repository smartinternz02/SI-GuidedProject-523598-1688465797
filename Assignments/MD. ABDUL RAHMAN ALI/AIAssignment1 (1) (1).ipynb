# %%
import pandas as pd
import numpy as np  
df=pd.DataFrame(np.random.rand(4,4))
df
# Out:
#           0         1         2         3
# 0  0.643898  0.724208  0.239066  0.680030
# 1  0.129206  0.829394  0.853619  0.871167
# 2  0.412563  0.866240  0.719729  0.054254
# 3  0.333388  0.821194  0.524333  0.854404

# %%
df.columns=['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.643898        0.724208        0.239066        0.680030
# 1        0.129206        0.829394        0.853619        0.871167
# 2        0.412563        0.866240        0.719729        0.054254
# 3        0.333388        0.821194        0.524333        0.854404

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.379764        0.810259        0.584187        0.614964
# std          0.212738        0.060620        0.266869        0.383667
# min          0.129206        0.724208        0.239066        0.054254
# 25%          0.282342        0.796947        0.453016        0.523586
# 50%          0.372975        0.825294        0.622031        0.767217
# 75%          0.470397        0.838606        0.753202        0.858595
# max          0.643898        0.866240        0.853619        0.871167

# %%
df.isnull()
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3           False           False           False           False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      float64
#  1   Random value 2  4 non-null      float64
#  2   Random value 3  4 non-null      float64
#  3   Random value 4  4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes

# %%
df.loc[:,'Random value 2':'Random value 3']
# Out:
#    Random value 2  Random value 3
# 0        0.724208        0.239066
# 1        0.829394        0.853619
# 2        0.866240        0.719729
# 3        0.821194        0.524333

# %%
df.iloc[:,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.724208        0.239066
# 1        0.829394        0.853619
# 2        0.866240        0.719729
# 3        0.821194        0.524333
